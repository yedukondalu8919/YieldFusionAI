# %% [markdown]
# # YieldFusionAI Colab Quick Start
# Upload this repository to Colab or clone it, install requirements, and run the training commands below.

# %%
# !pip install -q numpy pandas scikit-learn scipy matplotlib tensorflow opencv-python xgboost shap joblib

# %%
# !python -m src.train --mode proposed --epochs 5

# %%
# !python -m src.train --mode baselines
